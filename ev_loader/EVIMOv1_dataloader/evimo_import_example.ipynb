# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from ev_loader.EVIMOv1_dataloader.EVIMOSequence import EVIMOSequence
from ev_loader.utils.utils import render_events
# Out:
# Cannot import Open3d
# Cannot import Open3d

# %%
path = "/home/rpg/Downloads/EVIMO1/train/wall/seq_02.h5"

# %%
data = EVIMOSequence(path, window_ms=10.0, num_bins=2)
image_shape = (data.width, data.height)

# %%
rendered = render_events(data[0]["events"], image_shape)
plt.imshow(rendered)
plt.imshow(data[0]["mask"], alpha=0.5)
